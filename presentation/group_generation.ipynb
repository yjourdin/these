# %% [markdown]
# # Import

# %%
import warnings

warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
from src.performance_table.normal_performance_table import NormalPerformanceTable
from mcda.outranking.srmp import SRMP

# %% [markdown]
# # Alternatives

# %%
A = NormalPerformanceTable(
    [[6, 2], [4, 4], [2, 6]], alternatives=["A", "B", "C"]
)
A.plot()

# %% [markdown]
# # Modèles originaux

# %% [markdown]
# ## DM1

# %%
profile = NormalPerformanceTable([[1, 7]])
weights = dict(zip(range(2), [0, 0]))
DM1 = SRMP(A, weights, profile, [0])
SRMP.plot_input_data(A, DM1)
print("A=B=C")
# Out:
# A=B=C

# %% [markdown]
# ## DM2

# %%
profile = NormalPerformanceTable([[1, 3]])
DM2 = SRMP(A, weights, profile, [0])
SRMP.plot_input_data(A, DM2)
print("B=C > A")
# Out:
# B=C > A

# %% [markdown]
# ## Group

# %%
profile = NormalPerformanceTable([[1, 5]])
Group = SRMP(A, weights, profile, [0])
SRMP.plot_input_data(A, Group)
print("C > B=A")
# Out:
# C > B=A

# %% [markdown]
# # Modèles appris

# %% [markdown]
# ## Cas A=B=C

# %% [markdown]
# ### Group

# %%
profile = NormalPerformanceTable([[1, 1]])
Group = SRMP(A, weights, profile, [0])
SRMP.plot_input_data(A, Group)
print("A=B=C")
# Out:
# A=B=C

# %% [markdown]
# ### DM1

# %%
profile = NormalPerformanceTable([[1, 1]])
DM1 = SRMP(A, weights, profile, [0])
SRMP.plot_input_data(A, DM1)
print("A=B=C")
# Out:
# A=B=C

# %% [markdown]
# ### DM2

# %%
profile = NormalPerformanceTable([[1, 3]])
DM2 = SRMP(A, weights, profile, [0])
SRMP.plot_input_data(A, DM2)
print("B=C > A")
# Out:
# B=C > A

# %% [markdown]
# ## Cas B=C > A

# %% [markdown]
# ### Group

# %%
profile = NormalPerformanceTable([[1, 3]])
Group = SRMP(A, weights, profile, [0])
SRMP.plot_input_data(A, Group)
print("B=C > A")
# Out:
# B=C > A

# %% [markdown]
# ### DM1

# %%
profile = NormalPerformanceTable([[1, 1]])
DM1 = SRMP(A, weights, profile, [0])
SRMP.plot_input_data(A, DM1)
print("A=B=C")
# Out:
# A=B=C

# %% [markdown]
# ### DM2

# %%
profile = NormalPerformanceTable([[1, 3]])
DM2 = SRMP(A, weights, profile, [0])
SRMP.plot_input_data(A, DM2)
print("B=C > A")
# Out:
# B=C > A

# %% [markdown]
# ## Cas C > B=A

# %% [markdown]
# ### Group

# %%
profile = NormalPerformanceTable([[1, 5]])
Group = SRMP(A, weights, profile, [0])
SRMP.plot_input_data(A, Group)
print("C > A=B")
# Out:
# C > A=B

# %% [markdown]
# ### DM1

# %%
profile = NormalPerformanceTable([[1, 7]])
DM1 = SRMP(A, weights, profile, [0])
SRMP.plot_input_data(A, DM1)
print("A=B=C")
# Out:
# A=B=C

# %% [markdown]
# ### DM2

# %%
profile = NormalPerformanceTable([[1, 3]])
DM2 = SRMP(A, weights, profile, [0])
SRMP.plot_input_data(A, DM2)
print("B=C > A")
# Out:
# B=C > A

# %% [markdown]
# ## Cas B > A=C

# %% [markdown]
# ### Group

# %%
profile = NormalPerformanceTable([[3, 3]])
Group = SRMP(A, weights, profile, [0])
SRMP.plot_input_data(A, Group)
print("B > A=C")
# Out:
# B > A=C

# %% [markdown]
# ### DM1

# %%
profile = NormalPerformanceTable([[3, 5]])
DM1 = SRMP(A, weights, profile, [0])
SRMP.plot_input_data(A, DM1)
print("A=B=C")
# Out:
# A=B=C

# %% [markdown]
# ### DM2

# %%
profile = NormalPerformanceTable([[1, 3]])
DM2 = SRMP(A, weights, profile, [0])
SRMP.plot_input_data(A, DM2)
print("B=C > A")
# Out:
# B=C > A
