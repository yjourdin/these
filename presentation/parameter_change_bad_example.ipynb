# %% [markdown]
# # Import

# %%
import warnings

warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
from src.performance_table.normal_performance_table import NormalPerformanceTable
from mcda.outranking.srmp import SRMP

# %% [markdown]
# # Alternatives

# %%
A = NormalPerformanceTable(
    [[7, 1], [5, 3], [3, 5], [1, 7]], alternatives=["A", "B", "C", "D"]
)
A.plot()

# %% [markdown]
# # DM

# %%
profile = NormalPerformanceTable([[6, 8]])
weights = dict(zip(range(2), [0, 0]))
Group = SRMP(A, weights, profile, [0])
SRMP.plot_input_data(A, Group)
print("A > B=C=D")
# Out:
# A > B=C=D

# %% [markdown]
# # Group

# %%
profile = NormalPerformanceTable([[2, 8]])
DM = SRMP(A, weights, profile, [0])
SRMP.plot_input_data(A, DM)
print("A=B=C > D")
# Out:
# A=B=C > D

# %% [markdown]
# Liste de changements de préférences :
# 1.  Changements :
#     - **A > B --> A = B**
#     - **A > C --> A = C**
#     - **B = D --> B > D**
#     - **C = D --> C > D**

# %% [markdown]
# # 1 profil

# %%
profile = NormalPerformanceTable([[6, 8]])
Group = SRMP(A, weights, profile, [0])
SRMP.plot_input_data(A, Group)
print("A > B=C=D")
# Out:
# A > B=C=D

# %%
profile = NormalPerformanceTable([[4, 8]])
Group = SRMP(A, weights, profile, [0])
SRMP.plot_input_data(A, Group)
print("A=B > C=D")
# Out:
# A=B > C=D

# %%
profile = NormalPerformanceTable([[2, 8]])
Group = SRMP(A, weights, profile, [0])
SRMP.plot_input_data(A, Group)
print("A=B=C > D")
# Out:
# A=B=C > D

# %% [markdown]
# Liste de changements de préférences :
# 1.  Changements :
#     - **A > B --> A = B**
#     - **B = C --> B > C**
#     - **B = D --> B > D**
# 2.  Changements :
#     - A > B --> A = B
#     - ~~B = C --> B > C~~
#     - B = D --> B > D
#     - **A > C --> A = C**
#     - **C = D --> C > D**

# %% [markdown]
# # 2 profils

# %%
profiles = NormalPerformanceTable([[6, 8], [6, 8]])
weights = dict(zip(range(2), [0, 0]))
Group = SRMP(A, weights, profiles, [0, 1])
SRMP.plot_input_data(A, Group)
print("A > B=C=D")
# Out:
# A > B=C=D

# %%
profiles = NormalPerformanceTable([[6, 8], [4, 8]])
weights = dict(zip(range(2), [0, 0]))
Group = SRMP(A, weights, profiles, [0, 1])
SRMP.plot_input_data(A, Group)
print("A > B > C=D")
# Out:
# A > B > C=D

# %%
profiles = NormalPerformanceTable([[4, 8], [4, 8]])
weights = dict(zip(range(2), [0, 0]))
Group = SRMP(A, weights, profiles, [0, 1])
SRMP.plot_input_data(A, Group)
print("A=B > C=D")
# Out:
# A=B > C=D

# %%
profiles = NormalPerformanceTable([[4, 8], [2, 8]])
weights = dict(zip(range(2), [0, 0]))
Group = SRMP(A, weights, profiles, [0, 1])
SRMP.plot_input_data(A, Group)
print("A=B > C > D")
# Out:
# A=B > C > D

# %%
profiles = NormalPerformanceTable([[2, 8], [2, 8]])
weights = dict(zip(range(2), [0, 0]))
Group = SRMP(A, weights, profiles, [0, 1])
SRMP.plot_input_data(A, Group)
print("A=B=C > D")
# Out:
# A=B=C > D

# %% [markdown]
# Liste de changements de préférences :
# 1.  Changements :
#     - **B = C --> B > C**
#     - **B = D --> B > D**
# 2.  Changements :
#     - B = C --> B > C
#     - B = D --> B > D
#     - **A > B --> A = B**
# 3.  Changements :
#     - B = C --> B > C
#     - B = D --> B > D
#     - A > B --> A = B
#     - **C = D --> C > D**
# 4.  Changements :
#     - ~~B = C --> B > C~~
#     - B = D --> B > D
#     - A > B --> A = B
#     - C = D --> C > D
#     - **A > C --> A = C**

# %% [markdown]
# # 2 profils (alt.)

# %%
profiles = NormalPerformanceTable([[6, 8], [6, 8]])
weights = dict(zip(range(2), [0, 0]))
Group = SRMP(A, weights, profiles, [0, 1])
SRMP.plot_input_data(A, Group)
print("A > B=C=D")
# Out:
# A > B=C=D

# %%
profiles = NormalPerformanceTable([[6, 8], [4, 8]])
weights = dict(zip(range(2), [0, 0]))
Group = SRMP(A, weights, profiles, [0, 1])
SRMP.plot_input_data(A, Group)
print("A > B > C=D")
# Out:
# A > B > C=D

# %%
profiles = NormalPerformanceTable([[6, 8], [2, 8]])
weights = dict(zip(range(2), [0, 0]))
Group = SRMP(A, weights, profiles, [0, 1])
SRMP.plot_input_data(A, Group)
print("A > B=C > D")
# Out:
# A > B=C > D

# %%
profiles = NormalPerformanceTable([[4, 8], [2, 8]])
weights = dict(zip(range(2), [0, 0]))
Group = SRMP(A, weights, profiles, [0, 1])
SRMP.plot_input_data(A, Group)
print("A=B > C > D")
# Out:
# A=B > C > D

# %%
profiles = NormalPerformanceTable([[2, 8], [2, 8]])
weights = dict(zip(range(2), [0, 0]))
Group = SRMP(A, weights, profiles, [0, 1])
SRMP.plot_input_data(A, Group)
print("A=B=C > D")
# Out:
# A=B=C > D

# %% [markdown]
# Liste de changements de préférences :
# 1.  Changements :
#     - **B = C --> B > C**
#     - **B = D --> B > D**
# 2.  Changements :
#     - ~~B = C --> B > C~~
#     - B = D --> B > D
#     - **C = D --> C > D**
# 3.  Changements :
#     - B = D --> B > D
#     - C = D --> C > D
#     - **A > B --> A = B**
#     - **B = C --> B > C**
# 4.  Changements :
#     - B = D --> B > D
#     - C = D --> C > D
#     - A > B --> A = B
#     - ~~B = C --> B > C~~
#     - **A > C --> A = C**

# %% [markdown]
# Liste de changements de préférences :
# 1.  Changements :
#     - **B = D --> B > D**
#     - **C = D --> C > D**
# 2.  Changements :
#     - B = D --> B > D
#     - C = D --> C > D
#     - **A > B --> A = B**
#     - **B = C --> B > C**
# 3.  Changements :
#     - B = D --> B > D
#     - C = D --> C > D
#     - A > B --> A = B
#     - ~~B = C --> B > C~~
#     - **A > C --> A = C**

# %% [markdown]
# Liste de changements de préférences :
# 1.  Changements :
#     - **B = D --> B > D**
#     - **C = D --> C > D**
# 2.  Changements :
#     - B = D --> B > D
#     - C = D --> C > D
#     - **A > B --> A = B**
#     - **A > C --> A = C**
