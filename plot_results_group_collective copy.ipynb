# %% [markdown]
# # Import

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

# %% [markdown]
# # Results directory

# %%
RESULTS_DIR = Path("results/group_new_test")

# %% [markdown]
# # File

# %%
DATA = RESULTS_DIR / "compromise_results.csv"
MIP = RESULTS_DIR / "mip_results.csv"
PATH = RESULTS_DIR / "path_results.csv"

# %% [markdown]
# # Read files

# %%
df = pd.read_csv(DATA)
df_mip = pd.read_csv(MIP)
df_path = pd.read_csv(PATH)

# %% [markdown]
# # New attributes

# %% [markdown]
# # Merge data

# %% [markdown]
# # Filter

# %%
dff = df

# %%
dff
# Out:
#     M  N_tr  Atr_id  Ko  Mo_id  Group_size  Group  Mi_id  N_bc  Same_alt  \
# 0   3   100       2   2      2           2      0      2    10      True
# 1   3   100       3   2      3           2      0      3    10      True
# 2   3   100       2   2      2           2      0      2    10      True
# 3   3   100       9   2      9           2      0      9    10      True
# 4   3   100       3   2      3           2      0      3    10      True
# 5   3   100       6   2      6           2      0      6    10      True
# 6   3   100       7   2      7           2      0      7    10      True
# 7   3   100       5   2      5           2      0      5    10      True
# 8   3   100       8   2      8           2      0      8    10      True
# 9   3   100       9   2      9           2      0      9    10      True
# 10  3   100       7   2      7           2      0      7    10      True
# 11  3   100       5   2      5           2      0      5    10      True
# 12  3   100       6   2      6           2      0      6    10      True
# 13  3   100       8   2      8           2      0      8    10      True
# 14  3   100       0   2      0           2      0      0    10      True
# 15  3   100       1   2      1           2      0      1    10      True
# 16  3   100       0   2      0           2      0      0    10      True
# 17  3   100       1   2      1           2      0      1    10      True
# 18  3   100       4   2      4           2      0      4    10      True
# 19  3   100       4   2      4           2      0      4    10      True
#
#     D_id  Config  Mc_id   Path  P_id  Compromise       Time  It  Changes
# 0      2       0      2   True     2        True   0.064809   1        0
# 1      3       0      3   True     3        True   0.112840   1        0
# 2      2       0      2  False     2        True   0.091614   1        0
# 3      9       0      9   True     9        True   0.327052   1        1
# 4      3       0      3  False     3        True   0.097225   1        0
# 5      6       0      6   True     6        True   1.082348   1        3
# 6      7       0      7   True     7        True   0.880685   1        1
# 7      5       0      5   True     5        True   0.974745   1        4
# 8      8       0      8   True     8        True   0.833911   1        4
# 9      9       0      9  False     9        True   0.265947   1        1
# 10     7       0      7  False     7        True   1.142343   1        1
# 11     5       0      5  False     5        True   1.000856   1        4
# 12     6       0      6  False     6        True   1.171255   1        3
# 13     8       0      8  False     8        True   1.054539   1        4
# 14     0       0      0   True     0       False  60.042887   1        0
# 15     1       0      1   True     1       False  60.041259   1        0
# 16     0       0      0  False     0        True   1.481671   2        3
# 17     1       0      1  False     1        True   3.608146   3        4
# 18     4       0      4   True     4       False  59.620510   3        3
# 19     4       0      4  False     4       False  60.033774  24        0

# %%
df_mip
# Out:
# 56  3   100       4   2      4           2      0      4    10      True
# 57  3   100       4   2      4           2      0      4    10      True
# 58  3   100       4   2      4           2      0      4    10      True
# 59  3   100       4   2      4           2      0      4    10      True
#
#     D_id  Config  Mc_id   Path  P_id  It      Time  Fitness
# 0      2       0      2   True     2   0  0.040521      0.0
# 1      3       0      3   True     3   0  0.079202      0.0
# 2      2       0      2  False     2   0  0.060263      0.0
# 3      9       0      9   True     9   0  0.272747      1.0
# 4      3       0      3  False     3   0  0.064485      0.0
# 5      4       0      4   True     4   0  0.677100      2.0
# 6      0       0      0   True     0   0  0.749887      2.0
# 7      8       0      8   True     8   0  0.780878      2.0
# 8      7       0      7   True     7   0  0.843408      1.0
# 9      1       0      1   True     1   0  0.856888      2.0
# 10     5       0      5   True     5   0  0.921813      2.0
# 11     6       0      6   True     6   0  1.033417      2.0
# 12     9       0      9  False     9   0  0.218865      1.0
# 13     5       0      5  False     5   0  0.967063      2.0
# 14     8       0      8  False     8   0  0.993258      2.0
# 15     7       0      7  False     7   0  1.109569      1.0
# 16     6       0      6  False     6   0  1.119830      2.0
# 17     4       0      4   True     4   1  0.606028      3.0
# 18     4       0      4   True     4   2  0.677693      NaN
# 19     4       0      4   True     4   2  1.918272      NaN
# 20     4       0      4   True     4   2  1.918629      NaN
# 21     4       0      4   True     4   2  1.920716      NaN
# 22     0       0      0  False     0   0  0.578152      2.0
# 23     1       0      1  False     1   0  0.651778      2.0
# 24     4       0      4   True     4   2  1.826329      NaN
# 25     4       0      4   True     4   2  1.741834      NaN
# 26     0       0      0  False     0   1  0.841380      2.0
# 27     1       0      1  False     1   1  1.404488      2.0
# 28     4       0      4   True     4   2  1.762002      NaN
# 29     4       0      4   True     4   2  1.747158      NaN
# 30     1       0      1  False     1   2  1.453732      2.0
# 31     4       0      4   True     4   2  1.720372      NaN
# 32     4       0      4   True     4   2  1.715335      NaN
# 33     4       0      4  False     4   0  0.484588      2.0
# 34     4       0      4  False     4   1  1.257646      2.0
# 35     4       0      4  False     4   2  0.996456      2.0
# 36     4       0      4  False     4   3  1.305372      2.0
# 37     4       0      4  False     4   4  1.038423      2.0
# 38     4       0      4  False     4   5  0.798261      2.0
# 39     4       0      4  False     4   6  1.591526      2.0
# 40     4       0      4  False     4   7  1.888443      3.0
# 41     4       0      4  False     4   8  1.672792      3.0
# 42     4       0      4  False     4   9  1.822591      NaN
# 43     4       0      4  False     4   9  3.061392      3.0
# 44     4       0      4  False     4  10  2.684451      3.0
# 45     4       0      4  False     4  11  3.152080      3.0
# 46     4       0      4  False     4  12  3.109019      3.0
# 47     4       0      4  False     4  13  3.163051      3.0
# 48     4       0      4  False     4  14  2.433982      3.0
# 49     4       0      4  False     4  15  2.144323      3.0
# 50     4       0      4  False     4  16  2.901868      NaN
# 51     4       0      4  False     4  16  3.023380      3.0
# 52     4       0      4  False     4  17  3.965137      3.0
# 53     4       0      4  False     4  18  2.566724      3.0
# 54     4       0      4  False     4  19  3.035420      3.0
# 55     4       0      4  False     4  20  2.411696      3.0
# 56     4       0      4  False     4  21  3.147874      3.0
# 57     4       0      4  False     4  22  2.950044      3.0
# 58     4       0      4  False     4  23  0.944675      NaN
# 59     4       0      4  False     4  23  1.315663      3.0

# %%
df_path
# Out:
#    M  N_tr  Atr_id  Ko  Mo_id  Group_size  Group  Mi_id  N_bc  Same_alt  D_id  \
# 0  3   100       0   2      0           2      0      0    10      True     0
# 1  3   100       1   2      1           2      0      1    10      True     1
# 2  3   100       4   2      4           2      0      4    10      True     4
# 3  3   100       4   2      4           2      0      4    10      True     4
# 4  3   100       4   2      4           2      0      4    10      True     4
# 5  3   100       4   2      4           2      0      4    10      True     4
# 6  3   100       1   2      1           2      0      1    10      True     1
# 7  3   100       0   2      0           2      0      0    10      True     0
#
#    Config  Mc_id  Path  P_id  It  Dm_id       Time  Length  Model_Length
# 0       0      0  True     0   0      0   0.000002     1.0             2
# 1       0      1  True     1   0      1   0.807845     2.0             9
# 2       0      4  True     4   0      0  19.825035     2.0            20
# 3       0      4  True     4   0      1  40.963772     3.0            17
# 4       0      4  True     4   1      0   0.000002     1.0             2
# 5       0      4  True     4   1      1   0.000002     0.0             2
# 6       0      1  True     1   0      0  59.101002     NaN             0
# 7       0      0  True     0   0      1  59.199472     NaN             0

# %% [markdown]
# # Plot

# %% [markdown]
# ## Result

# %%
g = sns.catplot(
    dff,
    # x="Atr_id",
    x="Compromise",
    hue="Path",
    kind="count",
)
import tikzplotlib

tikzplotlib.save("mytikz.tex")

# %%
g = sns.catplot(
    dff,
    x="Atr_id",
    y="Time",
    hue="Path",
    kind="bar",
)
# plt.yscale("log")

# %%
g = sns.catplot(
    dff,
    x="Atr_id",
    y="It",
    hue="Path",
    kind="bar",
)

# %%
g = sns.catplot(
    dff,
    x="Atr_id",
    y="Changes",
    hue="Path",
    kind="bar",
)

# %% [markdown]
# ## MIP

# %%
g = sns.catplot(
    df_mip,
    x="Path",
    y="Time",
    hue="Path",
    kind="box"
)
# plt.yscale("log")

# %%
g = sns.catplot(
    df_mip,
    x="Path",
    y="Fitness",
    hue="Path",
    kind="box"
)
# plt.yscale("log")

# %% [markdown]
# ## Path

# %%
g = sns.catplot(
    df_path,
    x="Path",
    y="Time",
    hue="Path",
    kind="box"
)
# plt.yscale("log")

# %%
g = sns.catplot(
    df_path,
    x="Path",
    y="Length",
    hue="Path",
    kind="box"
)

# %%
g = sns.catplot(
    df_path,
    x="Path",
    y="Model_Length",
    hue="Path",
    kind="box"
)
