# %% [markdown]
# # Import

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tikzplotlib

# %% [markdown]
# # Results directory

# %%
RESULTS_DIR = Path("results/time_per_it_soft")

# %% [markdown]
# # File

# %%
DATA = RESULTS_DIR / "compromise_results.csv"
COLLECTIVE = RESULTS_DIR / "collective_results.csv"
PATH = RESULTS_DIR / "path_results.csv"

# %% [markdown]
# # Read files

# %%
df = pd.read_csv(DATA)
df_collective = pd.read_csv(COLLECTIVE)
df_path = pd.read_csv(PATH)

# %%
df
# Out:
#      M  N_tr  Atr_id  Ko  Mo_id  Group_size  Group  Mi_id  N_bc  Same_alt  \
# 0    3   100       3   1      3           2      0      3    10      True
# 1    3   100       5   1      5           2      0      5    10      True
# 2    3   100       9   1      9           2      0      9    10      True
# 3    3   100       4   1      4           2      0      4    10      True
# 4    3   100       7   1      7           2      0      7    10      True
# ..  ..   ...     ...  ..    ...         ...    ...    ...   ...       ...
# 101  3   100       5   2      5           2      0      5    50      True
# 102  3   100       8   2      8           2      0      8    50      True
# 103  3   100       1   3      1           2      0      1    30      True
# 104  3   100       6   3      6           2      0      6    40      True
# 105  3   100       5   3      5           2      0      5    50      True
#
#      ...  Mie_config Mie_id  Mc_id  Nb_Mcp  Path  P_id  Compromise  \
# 0    ...         NaN      3      3       1  True     3        True
# 1    ...         NaN      5      5       1  True     5        True
# 2    ...         NaN      9      9       1  True     9        True
# 3    ...         NaN      4      4       1  True     4        True
# 4    ...         NaN      7      7       1  True     7        True
# ..   ...         ...    ...    ...     ...   ...   ...         ...
# 101  ...         NaN      5      5       1  True     5        True
# 102  ...         NaN      8      8       1  True     8        True
# 103  ...         NaN      1      1       1  True     1        True
# 104  ...         NaN      6      6       1  True     6        True
# 105  ...         NaN      5      5       1  True     5        True
#
#            Time  It  Changes
# 0      0.999685   1        1
# 1      0.809814   1        0
# 2      0.933750   1        0
# 3      0.895493   1        0
# 4      0.915253   1        0
# ..          ...  ..      ...
# 101  300.951282   1        5
# 102  300.935347   1        7
# 103  301.505749   1        6
# 104  301.201646   1        4
# 105  301.382809   1        6
#
# [106 rows x 24 columns]

# %%
df_collective
# Out:
#      M  N_tr  Atr_id  Ko  Mo_id  Group_size  Group  Mi_id  N_bc  Same_alt  \
# 0    3   100       1   1      1           2      0      1    10      True
# 1    3   100       0   1      0           2      0      0    10      True
# 2    3   100       3   1      3           2      0      3    10      True
# 3    3   100       2   1      2           2      0      2    10      True
# 4    3   100       5   1      5           2      0      5    10      True
# ..  ..   ...     ...  ..    ...         ...    ...    ...   ...       ...
# 120  3   100       3   3      3           2      0      3    50      True
# 121  3   100       4   3      4           2      0      4    50      True
# 122  3   100       5   3      5           2      0      5    50      True
# 123  3   100       7   3      7           2      0      7    50      True
# 124  3   100       8   3      8           2      0      8    50      True
#
#      ...    Mie Mie_config  Mie_id  Mc_id  Nb_Mcp  Path  P_id  It        Time  \
# 0    ...  False        NaN       1      1       1  True     1   0    0.206901
# 1    ...  False        NaN       0      0       1  True     0   0    0.249014
# 2    ...  False        NaN       3      3       1  True     3   0    0.325512
# 3    ...  False        NaN       2      2       1  True     2   0    0.368969
# 4    ...  False        NaN       5      5       1  True     5   0    0.093654
# ..   ...    ...        ...     ...    ...     ...   ...   ...  ..         ...
# 120  ...  False        NaN       3      3       1  True     3   0  300.140942
# 121  ...  False        NaN       4      4       1  True     4   0  300.170216
# 122  ...  False        NaN       5      5       1  True     5   0  300.176588
# 123  ...  False        NaN       7      7       1  True     7   0  300.109140
# 124  ...  False        NaN       8      8       1  True     8   0  300.162026
#
#      Objective
# 0          1.0
# 1          2.0
# 2          1.0
# 3          1.0
# 4          0.0
# ..         ...
# 120        5.0
# 121        7.0
# 122        6.0
# 123       19.0
# 124        5.0
#
# [125 rows x 23 columns]

# %%
df_path
# Out:
#      M  N_tr  Atr_id  Ko  Mo_id  Group_size  Group  Mi_id  N_bc  Same_alt  \
# 0    3   100       3   1      3           2      0      3    10      True
# 1    3   100       2   1      2           2      0      2    10      True
# 2    3   100       2   1      2           2      0      2    10      True
# 3    3   100       0   1      0           2      0      0    10      True
# 4    3   100       1   1      1           2      0      1    10      True
# ..  ..   ...     ...  ..    ...         ...    ...    ...   ...       ...
# 216  3   100       6   3      6           2      0      6    40      True
# 217  3   100       2   3      2           2      0      2    50      True
# 218  3   100       4   3      4           2      0      4    50      True
# 219  3   100       5   3      5           2      0      5    50      True
# 220  3   100       5   3      5           2      0      5    50      True
#
#      ...  Mie_id Mc_id  Nb_Mcp  Path  P_id  It  Dm_id      Time  Length  \
# 0    ...       3     3       1  True     3   0      0  0.000003       1
# 1    ...       2     2       1  True     2   0      1  0.000004       1
# 2    ...       2     2       1  True     2   0      0  0.000003       1
# 3    ...       0     0       1  True     0   0      0  0.000003       1
# 4    ...       1     1       1  True     1   0      0  0.000004       0
# ..   ...     ...   ...     ...   ...   ...  ..    ...       ...     ...
# 216  ...       6     6       1  True     6   0      1  0.486053       1
# 217  ...       2     2       1  True     2   0      0  0.102311       2
# 218  ...       4     4       1  True     4   0      1  0.140353       4
# 219  ...       5     5       1  True     5   0      1  0.125581       2
# 220  ...       5     5       1  True     5   0      0  0.442880       3
#
#      Model_Length
# 0               2
# 1               2
# 2               2
# 3               2
# 4               2
# ..            ...
# 216             6
# 217             4
# 218             7
# 219             4
# 220             8
#
# [221 rows x 25 columns]

# %% [markdown]
# # New attributes

# %%
df["Gen"] = np.array(["Homogene", "Heterogene"])[df["Group"] % 2]
df["Accept"] = np.array(["Conservative", "Tolerant"])[df["Group"] % 2]

df["Changes_Prop"] = df["Changes"] / (df["N_bc"] * df["Group_size"])

df_collective["Objective_Prop"] = df_collective["Objective"] / df_collective["N_bc"]

# %%
for k in range(1, 4):
    for N in range(10, 60, 10):
        for i in range(10):
            if not len(df[(df["Atr_id"] == i) & (df["Ko"] == k) & (df["N_bc"] == N)]):
                df.loc[len(df)] = [3, 100, i, k, i, 2, 0, i, N, True, i, "mip", 0, False, None, i, i, 1, True, i, False, None, None, None, "Homogene", None, None]

# %%
df
# Out:
#      M  N_tr  Atr_id  Ko  Mo_id  Group_size  Group  Mi_id  N_bc  Same_alt  \
# 0    3   100       3   1      3           2      0      3    10      True
# 1    3   100       5   1      5           2      0      5    10      True
# 2    3   100       9   1      9           2      0      9    10      True
# 3    3   100       4   1      4           2      0      4    10      True
# 4    3   100       7   1      7           2      0      7    10      True
# ..  ..   ...     ...  ..    ...         ...    ...    ...   ...       ...
# 145  3   100       4   3      4           2      0      4    50      True
# 146  3   100       6   3      6           2      0      6    50      True
# 147  3   100       7   3      7           2      0      7    50      True
# 148  3   100       8   3      8           2      0      8    50      True
# 149  3   100       9   3      9           2      0      9    50      True
#
#      ...  Nb_Mcp  Path  P_id  Compromise      Time    It  Changes       Gen  \
# 0    ...       1  True     3        True  0.999685     1        1  Homogene
# 1    ...       1  True     5        True  0.809814     1        0  Homogene
# 2    ...       1  True     9        True   0.93375     1        0  Homogene
# 3    ...       1  True     4        True  0.895493     1        0  Homogene
# 4    ...       1  True     7        True  0.915253     1        0  Homogene
# ..   ...     ...   ...   ...         ...       ...   ...      ...       ...
# 145  ...       1  True     4       False      None  None     None  Homogene
# 146  ...       1  True     6       False      None  None     None  Homogene
# 147  ...       1  True     7       False      None  None     None  Homogene
# 148  ...       1  True     8       False      None  None     None  Homogene
# 149  ...       1  True     9       False      None  None     None  Homogene
#
#            Accept  Changes_Prop
# 0    Conservative          0.05
# 1    Conservative           0.0
# 2    Conservative           0.0
# 3    Conservative           0.0
# 4    Conservative           0.0
# ..            ...           ...
# 145          None          None
# 146          None          None
# 147          None          None
# 148          None          None
# 149          None          None
#
# [150 rows x 27 columns]

# %% [markdown]
# # Filter

# %%
# dff = df[df["Fitness_train"] == 1]
# dff = df[df["N_tr"].isin([10, 20, 30, 80, 90, 100])]
# dff = df[df["N_tr"] % 20 == 0]
dff = df
dff = dff[~df["Mie"]]
dff = dff.drop(columns=["Mie", "Mie_id"])
dff = dff[dff["Group_size"] == 2]
dff = dff[dff["Ko"] <= 3]
dff = dff[dff["Gen"] == "Homogene"]
dff = dff[dff["Path"]]
# dff = dff[dff["Compromise"]]
dff
# Out:
#      M  N_tr  Atr_id  Ko  Mo_id  Group_size  Group  Mi_id  N_bc  Same_alt  \
# 0    3   100       3   1      3           2      0      3    10      True
# 1    3   100       5   1      5           2      0      5    10      True
# 2    3   100       9   1      9           2      0      9    10      True
# 3    3   100       4   1      4           2      0      4    10      True
# 4    3   100       7   1      7           2      0      7    10      True
# ..  ..   ...     ...  ..    ...         ...    ...    ...   ...       ...
# 145  3   100       4   3      4           2      0      4    50      True
# 146  3   100       6   3      6           2      0      6    50      True
# 147  3   100       7   3      7           2      0      7    50      True
# 148  3   100       8   3      8           2      0      8    50      True
# 149  3   100       9   3      9           2      0      9    50      True
#
#      ...  Nb_Mcp  Path  P_id Compromise      Time    It  Changes       Gen  \
# 0    ...       1  True     3       True  0.999685     1        1  Homogene
# 1    ...       1  True     5       True  0.809814     1        0  Homogene
# 2    ...       1  True     9       True   0.93375     1        0  Homogene
# 3    ...       1  True     4       True  0.895493     1        0  Homogene
# 4    ...       1  True     7       True  0.915253     1        0  Homogene
# ..   ...     ...   ...   ...        ...       ...   ...      ...       ...
# 145  ...       1  True     4      False      None  None     None  Homogene
# 146  ...       1  True     6      False      None  None     None  Homogene
# 147  ...       1  True     7      False      None  None     None  Homogene
# 148  ...       1  True     8      False      None  None     None  Homogene
# 149  ...       1  True     9      False      None  None     None  Homogene
#
#            Accept Changes_Prop
# 0    Conservative         0.05
# 1    Conservative          0.0
# 2    Conservative          0.0
# 3    Conservative          0.0
# 4    Conservative          0.0
# ..            ...          ...
# 145          None         None
# 146          None         None
# 147          None         None
# 148          None         None
# 149          None         None
#
# [150 rows x 25 columns]

# %%
dff
# Out:
#      M  N_tr  Atr_id  Ko  Mo_id  Group_size  Group  Mi_id  N_bc  Same_alt  \
# 0    3   100       3   1      3           2      0      3    10      True
# 1    3   100       5   1      5           2      0      5    10      True
# 2    3   100       9   1      9           2      0      9    10      True
# 3    3   100       4   1      4           2      0      4    10      True
# 4    3   100       7   1      7           2      0      7    10      True
# ..  ..   ...     ...  ..    ...         ...    ...    ...   ...       ...
# 145  3   100       4   3      4           2      0      4    50      True
# 146  3   100       6   3      6           2      0      6    50      True
# 147  3   100       7   3      7           2      0      7    50      True
# 148  3   100       8   3      8           2      0      8    50      True
# 149  3   100       9   3      9           2      0      9    50      True
#
#      ...  Nb_Mcp  Path  P_id Compromise      Time    It  Changes       Gen  \
# 0    ...       1  True     3       True  0.999685     1        1  Homogene
# 1    ...       1  True     5       True  0.809814     1        0  Homogene
# 2    ...       1  True     9       True   0.93375     1        0  Homogene
# 3    ...       1  True     4       True  0.895493     1        0  Homogene
# 4    ...       1  True     7       True  0.915253     1        0  Homogene
# ..   ...     ...   ...   ...        ...       ...   ...      ...       ...
# 145  ...       1  True     4      False      None  None     None  Homogene
# 146  ...       1  True     6      False      None  None     None  Homogene
# 147  ...       1  True     7      False      None  None     None  Homogene
# 148  ...       1  True     8      False      None  None     None  Homogene
# 149  ...       1  True     9      False      None  None     None  Homogene
#
#            Accept Changes_Prop
# 0    Conservative         0.05
# 1    Conservative          0.0
# 2    Conservative          0.0
# 3    Conservative          0.0
# 4    Conservative          0.0
# ..            ...          ...
# 145          None         None
# 146          None         None
# 147          None         None
# 148          None         None
# 149          None         None
#
# [150 rows x 25 columns]

# %% [markdown]
# # Merge data

# %%
# df = pd.merge(
#     df_mip,
#     df_path,
#     how="left",
#     on=[
#         "M",
#         "N_tr",
#         "Atr_id",
#         "Ko",
#         "Mo_id",
#         "Group_size",
#         "Group",
#         "Mi_id",
#         "N_bc",
#         "Same_alt",
#         "D_id",
#         "Config",
#         "Mc_id",
#         "Path",
#         "P_id",
#         "It"
#     ],
#     suffixes=["_mip", "_path"],
# )


df_compromise_path = dff[dff["Path"]]
df_compromise_path = df_compromise_path[df_compromise_path["Compromise"]]
df_compromise_path_index = df_compromise_path.drop(
    columns=["Path", "Compromise", "Time", "It", "Changes", "Changes_Prop"]
)
df_compromise_no_path = dff[~dff["Path"]]
df_compromise_no_path = df_compromise_no_path[df_compromise_no_path["Compromise"]]
df_compromise_no_path_index = df_compromise_no_path.drop(
    columns=["Path", "Compromise", "Time", "It", "Changes", "Changes_Prop"]
)

df_compromise_index = pd.merge(
    df_compromise_path_index,
    df_compromise_no_path_index,
    how="inner",
    on=[
        "M",
        "N_tr",
        "Atr_id",
        "Ko",
        "Mo_id",
        "Group_size",
        "Group",
        "Mi_id",
        "N_bc",
        "Same_alt",
        "D_id",
        "Config",
        "P_id",
        "Mc_id",
        "P_id",
        "Gen",
        "Accept",
    ],
)

df_compromise_path = pd.merge(
    df_compromise_path,
    df_compromise_index,
    how="inner",
    on=[
        "M",
        "N_tr",
        "Atr_id",
        "Ko",
        "Mo_id",
        "Group_size",
        "Group",
        "Mi_id",
        "N_bc",
        "Same_alt",
        "D_id",
        "Config",
        "P_id",
        "Mc_id",
        "P_id",
        "Gen",
        "Accept",
    ],
    suffixes=["", ""],
)

df_compromise_no_path = pd.merge(
    df_compromise_no_path,
    df_compromise_index,
    how="inner",
    on=[
        "M",
        "N_tr",
        "Atr_id",
        "Ko",
        "Mo_id",
        "Group_size",
        "Group",
        "Mi_id",
        "N_bc",
        "Same_alt",
        "D_id",
        "Config",
        "P_id",
        "Mc_id",
        "P_id",
        "Gen",
        "Accept",
    ],
    suffixes=["", ""],
)

# df_compromise = pd.merge(
#     df_compromise_path,
#     df_compromise_no_path,
#     how="inner",
#     on=[
#         "M",
#         "N_tr",
#         "Atr_id",
#         "Ko",
#         "Mo_id",
#         "Group_size",
#         "Group",
#         "Mi_id",
#         "N_bc",
#         "Same_alt",
#         "D_id",
#         "Config",
#         "Mie",
#         "P_id",
#         "Mie_id",
#         "Mc_id",
#         "P_id",
#         "Gen",
#         "Accept"
#     ],
#     suffixes=["_path", "_no_path"],
# )

df_compromise = pd.concat([df_compromise_path, df_compromise_no_path])

df_compromise
# Out:
# Empty DataFrame
# Columns: [M, N_tr, Atr_id, Ko, Mo_id, Group_size, Group, Mi_id, N_bc, Same_alt, D_id, Method, Config, Mie_config, Mc_id, Nb_Mcp, Path, P_id, Compromise, Time, It, Changes, Gen, Accept, Changes_Prop, Method_x, Mie_config_x, Nb_Mcp_x, Method_y, Mie_config_y, Nb_Mcp_y]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # Plot

# %%
g = sns.relplot(
    dff,
    x="N_bc",
    y="Compromise",
    # row="Group_size",
    col="M",
    style="Ko",
    kind="line",
    errorbar=("ci", 95),
    err_style="bars",
    err_kws={"capsize": 5},
)
g.figure.subplots_adjust(top=0.9)
g.figure.suptitle("Proportion of instances reaching compromise")
# Out:
# Text(0.5, 0.98, 'Proportion of instances reaching compromise')

# %%
g = sns.relplot(
    df_collective,
    x="N_bc",
    y="Time",
    # row="Group_size",
    col="M",
    style="Ko",
    kind="line",
    errorbar=("ci", 95),
    err_style="bars",
    err_kws={"capsize": 5},
)
g.figure.subplots_adjust(top=0.9)
g.figure.suptitle("Computing time for collective model (MILP)")
# Out:
# Text(0.5, 0.98, 'Computing time for collective model (MILP)')

# %%
g = sns.relplot(
    df_path,
    x="N_bc",
    y="Time",
    # row="Group_size",
    col="M",
    style="Ko",
    kind="line",
    errorbar=("ci", 95),
    err_style="bars",
    err_kws={"capsize": 5},
)
g.figure.subplots_adjust(top=0.9)
g.figure.suptitle("Computing time for preference path")
# Out:
# Text(0.5, 0.98, 'Computing time for preference path')

# %%
g = sns.relplot(
    dff,
    x="N_bc",
    y="It",
    # row="Group_size",
    col="M",
    style="Ko",
    kind="line",
    errorbar=("ci", 95),
    err_style="bars",
    err_kws={"capsize": 5},
)
g.figure.subplots_adjust(top=0.9)
g.figure.suptitle("Number of iterations")
# Out:
# Text(0.5, 0.98, 'Number of iterations')

# %%
g = sns.relplot(
    df_collective,
    x="N_bc",
    y="Objective",
    # row="Group_size",
    col="M",
    style="Ko",
    kind="line",
    errorbar=("ci", 95),
    err_style="bars",
    err_kws={"capsize": 5},
)
g.figure.subplots_adjust(top=0.9)
g.figure.suptitle("Max number of comparisons to change for DMs")
# Out:
# Text(0.5, 0.98, 'Max number of comparisons to change for DMs')

# %%
g = sns.relplot(
    df_collective,
    x="N_bc",
    y="Objective_Prop",
    # row="Group_size",
    col="M",
    style="Ko",
    kind="line",
    errorbar=("ci", 95),
    err_style="bars",
    err_kws={"capsize": 5},
)
g.figure.subplots_adjust(top=0.9)
g.figure.suptitle("Max proportion of comparisons to change for DMs")
# Out:
# Text(0.5, 0.98, 'Max proportion of comparisons to change for DMs')
