# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("results/test_iter/train_results.csv")

# %%
df
# Out:
#     DM  N_tr  M    Mo  Ko  N_bc  Error    Me  Ke Method  Config        Time  \
# 0    0   500  7  SRMP   3   100      0  SRMP   3     SA       0   43.676661
# 1    1   500  7  SRMP   3   100      0  SRMP   3     SA       0   44.270761
# 2    2   500  7  SRMP   3   100      0  SRMP   3     SA       0   61.865366
# 3    1   500  7  SRMP   3   300      0  SRMP   3     SA       0  138.310163
# 4    0   500  7  SRMP   3   300      0  SRMP   3     SA       0  140.075772
# 5    3   500  7  SRMP   3   300      0  SRMP   3     SA       0  118.791054
# 6    1   500  7  SRMP   3   500      0  SRMP   3     SA       0  184.602973
# 7    0   500  7  SRMP   3   500      0  SRMP   3     SA       0  232.889446
# 8    3   500  7  SRMP   3   100      0  SRMP   3     SA       0   53.631953
# 9    4   500  7  SRMP   3   100      0  SRMP   3     SA       0   39.529634
# 10   2   500  7  SRMP   3   300      0  SRMP   3     SA       0  103.510762
# ...

# %%
sns.relplot(
    data=df,
    x="N_bc",
    y="Time",
    # style="Ke",
    # col="M",
    # row_order=["1", "2", "3", "4"],
    # col_order=["7", "11", "15"],
    kind="line",
    errorbar=("ci", 95),
    err_style="bars",
    err_kws={"capsize": 5},
)
